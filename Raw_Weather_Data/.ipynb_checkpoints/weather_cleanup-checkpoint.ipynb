# %%
import pandas as pd

# %%
csv_path = "Morelia_2000_2005.csv"
morelia_1  = pd.read_csv(csv_path, encoding="utf-8")
morelia_1
# Out:
#     Location                Address  Resolved Address         Period  \
# 0        NaN  Morelia, MICH, México               NaN  Week 52 (Dec)
# 1        NaN  Morelia, MICH, México               NaN   Week 1 (Jan)
# 2        NaN  Morelia, MICH, México               NaN   Week 2 (Jan)
# 3        NaN  Morelia, MICH, México               NaN   Week 3 (Jan)
# 4        NaN  Morelia, MICH, México               NaN   Week 4 (Jan)
# 5        NaN  Morelia, MICH, México               NaN   Week 5 (Jan)
# 6        NaN  Morelia, MICH, México               NaN   Week 6 (Feb)
# 7        NaN  Morelia, MICH, México               NaN   Week 7 (Feb)
# 8        NaN  Morelia, MICH, México               NaN   Week 8 (Feb)
# 9        NaN  Morelia, MICH, México               NaN   Week 9 (Feb)
# 10       NaN  Morelia, MICH, México               NaN  Week 10 (Mar)
# 11       NaN  Morelia, MICH, México               NaN  Week 11 (Mar)
# 12       NaN  Morelia, MICH, México               NaN  Week 12 (Mar)
# ...

# %%
for row in morelia_1['Period']:
