# %%
import pandas as pd
from sqlalchemy import create_engine
from config import password
password = password

# %%
# Define csvs
avo_data = "avo_prices.csv"
gas_data = "gas_prices.csv"

# %%
# Read in .csvs
avo_data_df = pd.read_csv(avo_data)
avo_data_df.head()
# Out:
#    Remaining Weeks in Year      Date  New Date  AveragePrice  Total Volume  \
# 0                       51  1/4/2015  1/5/2015          1.22      40873.28
# 1                       51  1/4/2015  1/5/2015          1.00     435021.49
# 2                       51  1/4/2015  1/5/2015          1.08     788025.06
# 3                       51  1/4/2015  1/5/2015          1.01      80034.32
# 4                       51  1/4/2015  1/5/2015          1.02     491738.00
#
#         4046       4225      4770  Total Bags  Small Bags  Large Bags  \
# 0    2819.50   28287.42     49.90     9716.46     9186.93      529.53
# 1  364302.39   23821.16     82.15    46815.79    16707.15    30108.64
# 2   53987.31  552906.04  39995.03   141136.68   137146.07     3990.61
# 3   44562.12   24964.23   2752.35     7755.62     6064.30     1691.32
# 4    7193.87  396752.18    128.82    87663.13    87406.84      256.29
#
#    XLarge Bags          type  year               region
# 0          0.0  conventional  2015               Albany
# 1          0.0  conventional  2015              Atlanta
# 2          0.0  conventional  2015  BaltimoreWashington
# 3          0.0  conventional  2015                Boise
# 4          0.0  conventional  2015               Boston

# %%
# Read in .csvs
gas_data_df = pd.read_csv(gas_data)
gas_data_df.head()
# Out:
#         Date  Gasoline - All Grades  All Grades - Conventional Areas  \
# 0  8/20/1990                    NaN                              NaN
# 1  8/27/1990                    NaN                              NaN
# 2   9/3/1990                    NaN                              NaN
# 3  9/10/1990                    NaN                              NaN
# 4  9/17/1990                    NaN                              NaN
#
#    All Grades - Reformulated Areas  Regular  Conventional Areas - Regular  \
# 0                              NaN    1.191                         1.191
# 1                              NaN    1.245                         1.245
# 2                              NaN    1.242                         1.242
# 3                              NaN    1.252                         1.252
# 4                              NaN    1.266                         1.266
#
#    Reformulated Areas - Regular  Midgrade  Conventional Areas - Midgrade  \
# 0                           NaN       NaN                            NaN
# 1                           NaN       NaN                            NaN
# 2                           NaN       NaN                            NaN
# 3                           NaN       NaN                            NaN
# 4                           NaN       NaN                            NaN
#
#    Reformulated Areas - Midgrade  Premium  Conventional Areas - Premium  \
# 0                            NaN      NaN                           NaN
# 1                            NaN      NaN                           NaN
# 2                            NaN      NaN                           NaN
# 3                            NaN      NaN                           NaN
# 4                            NaN      NaN                           NaN
#
#    Reformulated Areas - Premium  Diesel (On-Highway) - All Types  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                           NaN                              NaN
# 3                           NaN                              NaN
# 4                           NaN                              NaN
#
#    Ultra Low Sulfur (15 ppm and Under)  Low Sulfer (Above 15 ppm to 500 ppm)
# 0                                  NaN                                   NaN
# 1                                  NaN                                   NaN
# 2                                  NaN                                   NaN
# 3                                  NaN                                   NaN
# 4                                  NaN                                   NaN

# %%
# Create a filtered dataframe from specific columns
avo_columns = ["New Date", "AveragePrice", "Total Volume", "4046", "4225", "4770", "type", "year", "region"]
avo_transformed_df = avo_data_df[avo_columns].copy()

# Rename the column headers
avo_transformed_df = avo_transformed_df.rename(columns={"New Date": "date",
                                                        "AveragePrice": "average_price",
                                                        "Total Volume": "total_volume",
                                                       "4046": "small_avocados_sold",
                                                       "4225": "large_avocados_sold",
                                                       "4770": "xl_avocados_sold",
                                                       "type": "type",
                                                       "year": "year",
                                                       "region": "region"})

avo_transformed_df.head()
# Out:
#        date  average_price  total_volume  small_avocados_sold  \
# 0  1/5/2015           1.22      40873.28              2819.50
# 1  1/5/2015           1.00     435021.49            364302.39
# 2  1/5/2015           1.08     788025.06             53987.31
# 3  1/5/2015           1.01      80034.32             44562.12
# 4  1/5/2015           1.02     491738.00              7193.87
#
#    large_avocados_sold  xl_avocados_sold          type  year  \
# 0             28287.42             49.90  conventional  2015
# 1             23821.16             82.15  conventional  2015
# 2            552906.04          39995.03  conventional  2015
# 3             24964.23           2752.35  conventional  2015
# 4            396752.18            128.82  conventional  2015
#
#                 region
# 0               Albany
# 1              Atlanta
# 2  BaltimoreWashington
# 3                Boise
# 4               Boston

# %%
# Create a filtered dataframe from specific columns
gas_columns = ["Date", "Gasoline - All Grades", "Regular", "Midgrade", "Premium", "Diesel (On-Highway) - All Types"]
gas_transformed_df = gas_data_df[gas_columns].copy()

# Rename the column headers
gas_transformed_df = gas_transformed_df.rename(columns={"Date": "date",
                                                        "Gasoline - All Grades": "gas_all_grades",
                                                        "Regular": "regular",
                                                        "Midgrade": "midgrade",
                                                        "Premium": "premium",
                                                        "Diesel (On-Highway) - All Types": "diesel"})

gas_transformed_df.head()
# Out:
#         date  gas_all_grades  regular  midgrade  premium  diesel
# 0  8/20/1990             NaN    1.191       NaN      NaN     NaN
# 1  8/27/1990             NaN    1.245       NaN      NaN     NaN
# 2   9/3/1990             NaN    1.242       NaN      NaN     NaN
# 3  9/10/1990             NaN    1.252       NaN      NaN     NaN
# 4  9/17/1990             NaN    1.266       NaN      NaN     NaN

# %%
# Ensure dates have the same formatting
avo_transformed_df['date'] = pd.to_datetime(avo_transformed_df.date)
gas_transformed_df['date'] = pd.to_datetime(gas_transformed_df.date)

avo_transformed_df['date'] = avo_transformed_df['date'].dt.strftime('%m/%d/%Y')
gas_transformed_df['date'] = gas_transformed_df['date'].dt.strftime('%m/%d/%Y')

gas_transformed_df.head()
# Out:
#          date  gas_all_grades  regular  midgrade  premium  diesel
# 0  08/20/1990             NaN    1.191       NaN      NaN     NaN
# 1  08/27/1990             NaN    1.245       NaN      NaN     NaN
# 2  09/03/1990             NaN    1.242       NaN      NaN     NaN
# 3  09/10/1990             NaN    1.252       NaN      NaN     NaN
# 4  09/17/1990             NaN    1.266       NaN      NaN     NaN

# %%
# Filter data based on region and type
avo_transformed_df = avo_transformed_df.loc[avo_transformed_df['region'] == 'TotalUS']
avo_transformed_df = avo_transformed_df.loc[avo_transformed_df['type'] == 'conventional']
# from datetime import datetime, timedelta

# for date in avo_transformed_df['date']:
#     date += timedelta(days=1)
avo_transformed_df.head(20)
# Out:
#             date  average_price  total_volume  small_avocados_sold  \
# 51    01/05/2015           0.95   31324277.73          12357161.34
# 159   01/12/2015           1.01   29063542.75          11544810.53
# 267   01/19/2015           1.03   29043458.85          11858139.34
# 375   01/26/2015           1.04   28470310.84          12167445.03
# 483   02/02/2015           0.89   44655461.51          18933038.04
# 591   02/09/2015           0.95   32137333.01          13308193.40
# 699   02/16/2015           1.03   28012520.93          12626615.30
# 807   02/23/2015           1.02   29936729.76          12628562.36
# 915   03/02/2015           0.97   32994014.16          13282222.98
# 1023  03/09/2015           1.02   30094698.85          13013750.35
# 1131  03/16/2015           1.04   29572225.71          13149988.71
# 1239  03/23/2015           1.01   32513550.51          13697405.61
# 1347  03/30/2015           1.04   29982648.43          12524637.04
# 1455  04/06/2015           1.06   31500669.44          13939014.43
# 1563  04/13/2015           1.02   32046401.64          14793354.18
# 1671  04/20/2015           1.03   33091256.26          14251319.31
# 1779  04/27/2015           1.07   30894157.80          13833715.28
# 1887  05/04/2015           0.96   41291704.39          17787611.93
# 1995  05/11/2015           1.02   36400886.58          16215328.75
# 2103  05/18/2015           1.06   32027686.15          14615941.59
#
#       large_avocados_sold  xl_avocados_sold          type  year   region
# 51            13624083.05         844093.32  conventional  2015  TotalUS
# 159           12134773.38         866574.66  conventional  2015  TotalUS
# 267           11701947.80         831301.90  conventional  2015  TotalUS
# 375           10734652.82         768020.05  conventional  2015  TotalUS
# 483           18956479.74        1381516.11  conventional  2015  TotalUS
# 591           13381347.54         737939.45  conventional  2015  TotalUS
# 699            9783489.59         845653.52  conventional  2015  TotalUS
# 807           11354281.64         937138.85  conventional  2015  TotalUS
# 915           13733124.48        1070576.07  conventional  2015  TotalUS
# 1023          10973972.60         834009.15  conventional  2015  TotalUS
# 1131          10634070.76         871575.04  conventional  2015  TotalUS
# 1239          12659784.83        1066385.92  conventional  2015  TotalUS
# 1347          11541041.35         811272.88  conventional  2015  TotalUS
# 1455          11526980.36         871981.29  conventional  2015  TotalUS
# 1563          11210544.11         807942.41  conventional  2015  TotalUS
# 1671          12277858.78        1016631.26  conventional  2015  TotalUS
# 1779          10867403.08         889732.20  conventional  2015  TotalUS
# 1887          16602589.04        1118329.50  conventional  2015  TotalUS
# 1995          13509064.65         858145.45  conventional  2015  TotalUS
# 2103          11003341.22         963549.53  conventional  2015  TotalUS

# %%
# Create database connection
connection_string = (f"postgres:{password}@localhost:5432/etl_project_db")
engine = create_engine(f'postgresql://{connection_string}')

# %%
avo_transformed_df.to_sql(name='avocado', con=engine, if_exists='append', index=False)
gas_transformed_df.to_sql(name='gas', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from avocado', con=engine).head()
# Out:
#          date  average_price  total_volume  small_avocados_sold  \
# 0  01/05/2015           0.95   31324277.73          12357161.34
# 1  01/12/2015           1.01   29063542.75          11544810.53
# 2  01/19/2015           1.03   29043458.85          11858139.34
# 3  01/26/2015           1.04   28470310.84          12167445.03
# 4  02/02/2015           0.89   44655461.51          18933038.04
#
#    large_avocados_sold  xl_avocados_sold          type  year   region
# 0          13624083.05         844093.32  conventional  2015  TotalUS
# 1          12134773.38         866574.66  conventional  2015  TotalUS
# 2          11701947.80         831301.90  conventional  2015  TotalUS
# 3          10734652.82         768020.05  conventional  2015  TotalUS
# 4          18956479.74        1381516.11  conventional  2015  TotalUS

# %%
pd.read_sql_query('select * from gas', con=engine).head()
# Out:
#          date  gas_all_grades  regular  midgrade  premium  diesel
# 0  08/20/1990             NaN    1.191       NaN      NaN     NaN
# 1  08/27/1990             NaN    1.245       NaN      NaN     NaN
# 2  09/03/1990             NaN    1.242       NaN      NaN     NaN
# 3  09/10/1990             NaN    1.252       NaN      NaN     NaN
# 4  09/17/1990             NaN    1.266       NaN      NaN     NaN
