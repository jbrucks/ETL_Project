# %%
import json
import requests

# %%
# This .ipynb file is using an API service from NOAA's Historical Observing Metadata Repository. For the future, we will use it
# to gather weather data for specific areas that grow avocados.

# %%
url = "http://www.ncdc.noaa.gov/homr/services/station/722223?date=all"

# %%
requests.get(url).json()
# Out:
# {'stationCollection': {'definitions': [{'defType': 'ids',
#     'abbr': 'GHCND',
#     'fullName': 'GHCND IDENTIFIER',
#     'displayName': 'GHCND ID',
#     'description': 'GLOBAL HISTORICAL CLIMATOLOGY NETWORK - DAILY (GHCND) IDENTIFIER'},
#    {'defType': 'ids',
#     'abbr': 'COOP',
#     'fullName': 'COOP NUMBER',
#     'displayName': 'COOP ID',
#     'description': 'NATIONAL WEATHER SERVICE COOPERATIVE NETWORK IDENTIFIER'},
#    {'defType': 'ids',
#     'abbr': 'WBAN',
#     'fullName': 'WBAN NUMBER',
#     'displayName': 'WBAN ID',
#     'description': 'WEATHER-BUREAU-ARMY-NAVY IDENTIFIER'},
#    {'defType': 'ids',
#     'abbr': 'FAA',
#     'fullName': 'FAA LOCATION IDENTIFIER',
#     'displayName': 'FAA ID',
#     'description': 'FEDERAL AVIATION ADMINISTRATION IDENTIFIER'},
#    {'defType': 'ids',
#     'abbr': 'ICAO',
#     'fullName': 'ICAO ID',
#     'displayName': 'ICAO ID',
#     'description': 'INTERNATIONAL CIVIL AVIATION ORGANIZATION IDENTIFIER'},
# ...

# %%
requests.get(url).json().keys
# Out:
# <function dict.keys>

# %%
# response = requests.get(url).json()
# response

# %%
# 766650 99999 MORELIA  MICH.                MX            +19.700 -101.183 +1913.0 19730103 20200715
# Morelia, Michocan, Mexico

# %%
# 722223 13899 PENSACOLA REGIONAL AIRPORT    US   FL KPNS  +30.478 -087.187 +0034.1 19900228 20200716
# Testing a call to the Pensacola, FL station.
